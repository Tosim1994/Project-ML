# %% [markdown]
# Step1 - Gathering dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv('/content/Housing (1).csv')
data.info()
data.describe()
data.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# ...

# %%
data['mainroad']=data['mainroad'].apply({'yes':1,'no':0}.get)
data['guestroom']=data['guestroom'].apply({'yes':1,'no':0}.get)
data['basement']=data['basement'].apply({'yes':1,'no':0}.get)
data['hotwaterheating']=data['hotwaterheating'].apply({'yes':1,'no':0}.get)
data['airconditioning']=data['airconditioning'].apply({'yes':1,'no':0}.get)
data['prefarea']=data['prefarea'].apply({'yes':1,'no':0}.get)
data['furnishingstatus']=data['furnishingstatus'].apply({'furnished':1,'semi-furnished':2,'unfurnished':3}.get)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    int64
#  6   guestroom         545 non-null    int64
#  7   basement          545 non-null    int64
#  8   hotwaterheating   545 non-null    int64
#  9   airconditioning   545 non-null    int64
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    int64
#  12  furnishingstatus  545 non-null    int64
# dtypes: int64(13)
# memory usage: 55.5 KB

# %%
ax=data.plot(figsize=(10,15),title='Housing')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
ax=data.iloc[1].plot(figsize=(10,15),title='Housing')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
ax=data.iloc[0:2].plot(figsize=(10,15),title='Housing')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
data.plot.scatter(x='area',y='price',c='stories')

# %%
data.plot.scatter(x='area',y='price')

# %%
sns.catplot(data=data,x='stories',y='price')
sns.catplot(data=data,x='stories',y='price',kind='box')
sns.catplot(data=data,x='stories',y='price',kind='violin')

# %%
data.plot.scatter(x='stories',y='price')

# %%
data.plot.scatter(x='bathrooms',y='price')

# %%
sns.catplot(data=data,x='bathrooms',y='price',kind='box')

# %%
sns.catplot(data=data,x='bathrooms',y='price',kind='violin')
sns.catplot(data=data,x='bathrooms',y='price',kind='box')

# %%
sns.pairplot(data=data,x_vars=['area','bedrooms','bathrooms'],y_vars=['price'],size=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=data,x_vars=['stories','mainroad','guestroom'],y_vars=['price'],size=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=data,x_vars=['basement','hotwaterheating','airconditioning'],y_vars=['price'],size=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data=data,x_vars=['parking','prefarea','furnishingstatus'],y_vars=['price'],size=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
x=data[['area','bedrooms','bathrooms','stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus']]
y=data['price']

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train.shape
# Out:
# (436, 12)

# %%
y_train.shape
# Out:
# (436,)

# %%
x_test.shape
# Out:
# (109, 12)

# %%
y_test.shape
# Out:
# (109,)

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=regression.predict(x_test)

# %%
predictions
# Out:
# array([ 4732584.65292476,  6537153.90751959,  7891043.12126958,
#         4308898.17397861,  3716474.14197277,  8300204.47403264,
#         3616817.37265848,  4197777.69565258,  6112374.73252754,
#         4454826.72707665,  5692205.11817106,  4299614.69138992,
#         4958726.93955485,  5207550.07103399,  4626912.66613785,
#         5412616.88366563,  4371149.31726686,  6229542.54117739,
#         2767311.95431498,  4607470.34190927,  2537017.27483887,
#         6516491.32775886,  3447276.76232635,  6266469.56206548,
#         3162782.45302145,  5782986.93386221,  4987796.70592053,
#         6737265.89658504,  2947816.90583849,  5868258.63272702,
#         3795242.54554041,  5062992.32786525,  4734794.46312181,
#         7774579.70369787,  6365108.89176597,  7373204.99984714,
#         2722787.62555503,  2720244.52205308,  3592545.79640679,
#         4664410.12949685,  8386192.9510731 ,  6331218.77274754,
#         7209303.1356536 ,  3322418.2594506 ,  2613133.67923908,
# ...

# %%
regression.score(x,y)
# Out:
# 0.6787243847974609

# %%
new_data={'area':input('enter the area in Sq Feet : '),'bedrooms':input('enter no of bedrooms : '),'bathrooms':input('enter no of bathroom : '),'stories':input('no of stories on which property situated : '),'mainroad':input('enter 1 if property is near mainroad otherwise enter 0: '),'guestroom':input('if property have guestroom Yes type 1 no type 0: '),'basement':input('if we have basment yes type 1 for no type 0 : '),'hotwaterheating':input('if property have Heating water yes type 1 for No type 0: '),'airconditioning':input('is we have AC yes type 1 for No 0: '),'parking':input('enter no of parking: '),'prefarea':input('if prefarea is yes type 1 for no type 0: '),'furnishingstatus':input('If furnished type 1 semifernished type 2 unfurnished type 0: ')}
index=[1]
new_data=pd.DataFrame(new_data,index)
new_data
new_predictions=regression.predict(new_data)
print(new_predictions,'will be the price of new house')
# Out:
# enter the area in Sq Feet : 10000
# enter no of bedrooms : 4
# enter no of bathroom : 4
# no of stories on which property situated : 1
# enter 1 if property is near mainroad otherwise enter 0: 1
# if property have guestroom Yes type 1 no type 0: 1
# if we have basment yes type 1 for no type 0 : 1
# if property have Heating water yes type 1 for No type 0: 1
# is we have AC yes type 1 for No 0: 1
# enter no of parking: 1
# if prefarea is yes type 1 for no type 0: 1
# If furnished type 1 semifernished type 2 unfurnished type 0: 1
# [11272966.68120831] will be the price of new house
